# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %%
import numpy as np
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Input, Dense
import matplotlib.pyplot as plt

# %%
# 1. data set
x_data = np.array([[0, 0],
                   [0, 1],
                   [1, 0], 
                   [1, 1]])
y_data = np.array([[0], [1], [1], [0]])
# 2. 모델구성
model = Sequential()
# model.add(Input(shape=2))
model.add(Dense(units=10, # 출력 갯수
               input_dim=2, # input_shape = (2,) # 입력 갯수
               activation='relu')) # 활성화 함수
model.add(Dense(units=20, activation='relu')) # 은닉층에서는 input_shape는 X
model.add(Dense(10, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
print(model.summary())
# 3. 모델 학습과정 설정
    # loss : mae(회귀분석), binary_crossentropy(이진분류=로지스틱회귀분석), 
            # categorical_crossentropy(다중분류-원핫인코딩을 한 경우)
            # sparse_categorical_crossentropy(다중분류-원핫인코딩을 안 한 경우)
model.compile(loss = 'binary_crossentropy',  # 손실함수(loss function)
             optimizer= 'adam',
             metrics=['binary_accuracy']) # 2진분류
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 10)                30
#
#  dense_13 (Dense)            (None, 20)                220
#
#  dense_14 (Dense)            (None, 10)                210
#
#  dense_15 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 4. 학습
hist = model.fit(x_data, y_data, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 1/1 - 1s - loss: 0.7169 - binary_accuracy: 0.5000 - 609ms/epoch - 609ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 0.7141 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 0.7111 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 0.7084 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 0.7060 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 0.7038 - binary_accuracy: 0.2500 - 1ms/epoch - 1ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 0.7018 - binary_accuracy: 0.2500 - 1ms/epoch - 1ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 0.6995 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 0.6972 - binary_accuracy: 0.2500 - 1ms/epoch - 1ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 0.6950 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 0.6928 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 0.6907 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 0.6886 - binary_accuracy: 0.5000 - 1ms/epoch - 1ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 0.6865 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 0.6845 - binary_accuracy: 0.5000 - 1ms/epoch - 1ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 0.6823 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 0.6802 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 0.6782 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 0.6762 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 0.6741 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 0.6720 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 0.6705 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 0.6690 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 0.6672 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 0.6654 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 0.6635 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 0.6617 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 0.6601 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 0.6585 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 0.6568 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 0.6550 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 0.6532 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 0.6513 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 0.6498 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 0.6481 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 0.6463 - binary_accuracy: 0.7500 - 1ms/epoch - 1ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 0.6446 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 0.6429 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 0.6413 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 0.6395 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 0.6378 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 0.6362 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 0.6345 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 0.6327 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 0.6312 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 0.6296 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 0.6278 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 0.6262 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 0.6246 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 0.6229 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 0.6211 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 0.6195 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 0.6177 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 0.6159 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 0.6141 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 0.6125 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 0.6106 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 0.6086 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 0.6069 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 0.6051 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 0.6032 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 0.6012 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 0.5995 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 0.5977 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 0.5958 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 0.5937 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 0.5916 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 0.5897 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 0.5879 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 0.5860 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 0.5841 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 0.5820 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 0.5800 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 0.5782 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 0.5764 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 0.5744 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 0.5725 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 0.5705 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 0.5684 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 0.5663 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 0.5642 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 0.5622 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 0.5602 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 0.5580 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 0.5559 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 0.5537 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 0.5515 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 0.5495 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 0.5474 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 0.5452 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 0.5430 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 0.5407 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 0.5384 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 0.5363 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 0.5341 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 0.5317 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 0.5292 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 0.5267 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 0.5245 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 0.5219 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 0.5194 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 0.5170 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 0.5145 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 0.5119 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 0.5094 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 0.5068 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 0.5042 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 0.5016 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 0.4992 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 0.4966 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 0.4939 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 0.4913 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 0.4887 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.4860 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.4834 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.4806 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.4780 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.4753 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.4725 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.4697 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.4670 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.4642 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.4614 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.4585 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.4557 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.4528 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.4500 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.4471 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.4442 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.4415 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.4386 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.4357 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.4327 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.4299 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.4271 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.4241 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.4213 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.4185 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.4155 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.4126 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.4097 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.4067 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.4038 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.4009 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.3980 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.3950 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.3921 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.3893 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.3863 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.3834 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.3806 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.3777 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.3748 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.3719 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.3691 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.3662 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.3633 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.3604 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.3576 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.3548 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.3520 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.3492 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.3464 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.3434 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.3406 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.3379 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.3350 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.3322 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.3296 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.3267 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.3239 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.3211 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.3185 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.3159 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.3132 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.3104 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.3077 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.3051 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.3026 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.3000 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.2974 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.2948 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.2923 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.2898 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.2872 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.2848 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.2824 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.2798 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.2774 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.2750 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.2726 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.2702 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.2679 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.2656 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.2632 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.2610 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.2588 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.2565 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.2543 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.2522 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.2500 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.2479 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.2457 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.2436 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.2415 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.2395 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.2374 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.2355 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.2335 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.2315 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.2295 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.2277 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.2257 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.2238 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.2220 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.2201 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.2183 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.2165 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.2148 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.2131 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.2113 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.2095 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.2079 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.2062 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.2045 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.2028 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.2012 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.1996 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.1980 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.1965 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.1950 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.1934 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.1919 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.1904 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.1889 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.1875 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.1860 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.1846 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.1832 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.1818 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.1804 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.1791 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.1777 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.1763 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.1750 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.1737 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.1723 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.1710 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.1697 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.1683 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.1668 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.1654 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.1638 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.1623 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.1607 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.1592 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.1576 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.1561 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.1546 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.1531 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.1515 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.1500 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.1485 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.1470 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.1456 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.1440 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.1426 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.1411 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.1397 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.1382 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.1368 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.1355 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.1341 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.1328 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.1317 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.1304 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.1292 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.1278 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.1265 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.1252 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.1239 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.1226 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.1214 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.1202 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.1190 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.1179 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.1167 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.1155 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.1143 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.1132 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.1121 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.1109 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.1098 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.1087 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.1076 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.1065 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.1055 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.1044 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.1033 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.1023 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step

# %%
#5. 학습과정 살펴보기
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'b', label='loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax
acc_ax.plot(hist.history['binary_accuracy'], 'r', label='binary_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary_accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='center left')
plt.show()

# %%
# 모델 평가하기
score = model.evaluate(x_data, y_data)# loss & metrics(binary_accuracy)
print('loss:',score[0])
print('accuracy :', score[1])
# Out:
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1013 - binary_accuracy: 1.0000
# loss: 0.10127831250429153
# accuracy : 1.0

# %%
# 예측하기
model.predict(np.array([[0, 1]]))
# Out:
# 1/1 [==============================] - 0s 151ms/step
# array([[0.9466795]], dtype=float32)
